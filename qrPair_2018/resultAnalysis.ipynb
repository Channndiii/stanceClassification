# %%
import pandas as pd
import numpy as np

# %%
def getFinalDf(task, Type):
    result_df = pd.read_csv('./data/result_hybrid.csv')
    result_df = result_df[result_df.task == task]
    result_Type_df = result_df[result_df.type == Type]
    
    target_epoch = [str(i) for i in range(10, 101, 10)]
    result_Type_df['rowFilter'] = result_Type_df['fold_epoch'].apply(lambda fold_epoch: fold_epoch.split('_')[-1] in target_epoch)
    
    result_Type_df = result_Type_df[result_Type_df.rowFilter == True]
    
    result = np.asarray(result_Type_df.values[:, [4, 5, 6, 7, 8, 9]])
    final_df = pd.DataFrame(np.mean(result.reshape([5, -1, 6]), axis=0), 
                            columns=['train_acc', 'train_cost', 'test_acc', 'test_cost', 'disagree_f1', 'agree_f1'])
    def computeAverageF1(row):
        row['average_f1'] = (row['disagree_f1'] + row['agree_f1']) / 2
        return row
    final_df = final_df.apply(computeAverageF1, axis=1)
    return final_df

# %%
getFinalDf(task='iac', Type='None')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.989341    0.035876  0.747447   2.129202      0.81374   0.60710
# 1   0.994820    0.021685  0.740979   3.066432      0.81162   0.58476
# 2   0.996276    0.014642  0.748637   3.481449      0.81582   0.60362
# 3   0.997860    0.008666  0.744212   3.719941      0.80948   0.60912
# 4   0.999358    0.003621  0.752724   4.041685      0.81852   0.61134
# 5   0.999187    0.003133  0.753575   4.119003      0.81862   0.61556
# 6   0.999700    0.001384  0.754766   4.219542      0.82144   0.60850
# ...

# %%
getFinalDf(task='iac', Type='share')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.991781    0.026465  0.747618   2.199600      0.81570   0.59924
# 1   0.993707    0.026246  0.748808   2.943007      0.81462   0.61006
# 2   0.996789    0.013131  0.748806   3.405222      0.81434   0.61094
# 3   0.997860    0.009003  0.754086   3.603056      0.82094   0.60668
# 4   0.998887    0.004249  0.749830   3.856151      0.81668   0.60432
# 5   0.999658    0.001293  0.755277   3.945557      0.82188   0.60772
# 6   0.999486    0.001154  0.757488   4.005468      0.82244   0.61738
# ...

# %%
getFinalDf(task='iac', Type='self_attention')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.992551    0.023400  0.753237   2.292924      0.82060   0.60354
# 1   0.995205    0.018573  0.751704   3.030203      0.81680   0.61142
# 2   0.996190    0.017162  0.753748   3.379491      0.81710   0.62188
# 3   0.998160    0.006838  0.756807   3.792894      0.82378   0.60738
# 4   0.998844    0.004955  0.760379   3.909403      0.82462   0.61982
# 5   0.999272    0.002313  0.758337   4.042920      0.82090   0.62752
# 6   0.999615    0.001153  0.755788   4.171384      0.82094   0.61494
# ...

# %%
getFinalDf(task='iac', Type='cross_attention')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.990454    0.033187  0.747788   2.160724      0.81758   0.59126
# 1   0.994863    0.018032  0.748810   2.961367      0.81408   0.61270
# 2   0.995591    0.019034  0.753405   3.266451      0.81658   0.62342
# 3   0.997945    0.008582  0.755447   3.581428      0.81980   0.61874
# 4   0.998716    0.005221  0.760040   3.846836      0.82616   0.61228
# 5   0.999529    0.001879  0.757318   3.970963      0.82248   0.61624
# 6   0.999358    0.002680  0.758168   4.194565      0.82252   0.61986
# ...

# %%
getFinalDf(task='iac', Type='both_sum')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0

# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.991139    0.032106  0.748640   2.394993      0.81426   0.61112
# 1   0.994435    0.023449  0.752385   3.142009      0.82030   0.60048
# 2   0.995334    0.022563  0.753917   3.756195      0.81784   0.62076
# 3   0.998074    0.008456  0.756130   4.115115      0.82072   0.61716
# 4   0.998673    0.005778  0.756469   4.418968      0.82094   0.61934
# 5   0.999230    0.002785  0.755617   4.624515      0.81922   0.62142
# 6   0.999272    0.002948  0.756809   4.600755      0.82334   0.60926
# ...

# %%
def getFinalDf_v2(task, Type):
    result_df = pd.read_csv('./data/result_hybrid.csv')
    result_df = result_df[result_df.task == task]
    result_Type_df = result_df[result_df.type == Type]
    
    target_epoch = [str(i) for i in range(101)]
    result_Type_df['rowFilter'] = result_Type_df['fold_epoch'].apply(lambda fold_epoch: fold_epoch.split('_')[-1] in target_epoch)
    
    result_Type_df = result_Type_df[result_Type_df.rowFilter == True]
    
    result = np.asarray(result_Type_df.values[:, [4, 5, 6, 7, 8, 9]])
    final_df = pd.DataFrame(np.mean(result.reshape([5, -1, 6]), axis=0), 
                            columns=['train_acc', 'train_cost', 'test_acc', 'test_cost', 'disagree_f1', 'agree_f1'])
    def computeAverageF1(row):
        row['average_f1'] = (row['disagree_f1'] + row['agree_f1']) / 2
        return row
    final_df = final_df.apply(computeAverageF1, axis=1)
    return final_df

# %%
getFinalDf_v2(task='iac_MTL', Type='cross_attention').to_csv('./data/iac_MTL_result.csv')

# %%
getFinalDf(task='iac_shuffle_0420', Type='None')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.989769    0.032160  0.735196   1.990249      0.80486   0.58788
# 1   0.995163    0.018355  0.743196   2.729512      0.81116   0.59690
# 2   0.995248    0.018423  0.748981   3.179593      0.81888   0.58986
# 3   0.998416    0.006244  0.743366   3.546114      0.81036   0.60272
# 4   0.998930    0.004016  0.746258   3.846396      0.81482   0.59466
# 5   0.999529    0.002503  0.749662   3.964662      0.81834   0.59734
# 6   0.999572    0.001930  0.753067   3.993178      0.82166   0.59842
# ...

# %%
getFinalDf(task='iac_shuffle_0420', Type='self_attention')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.992680    0.023133  0.750169   2.165868      0.81840   0.59812
# 1   0.995548    0.013451  0.748980   2.802513      0.81898   0.58826
# 2   0.996104    0.015992  0.750682   3.235872      0.81928   0.59778
# 3   0.998159    0.007402  0.753235   3.636919      0.81872   0.61334
# 4   0.998759    0.005897  0.751194   3.874240      0.81674   0.61076
# 5   0.999401    0.002371  0.754085   3.963552      0.82036   0.60926
# 6   0.999315    0.002941  0.755959   4.052225      0.82114   0.61458
# ...

# %%
getFinalDf(task='iac_shuffle_0420', Type='cross_attention')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.992423    0.024886  0.746936   1.976630      0.81190   0.61146
# 1   0.994991    0.017525  0.742169   2.842197      0.80798   0.60562
# 2   0.996190    0.016589  0.754594   3.195671      0.82140   0.60548
# 3   0.998117    0.007193  0.756637   3.403553      0.82280   0.61140
# 4   0.999144    0.003284  0.749150   3.622559      0.81458   0.61212
# 5   0.999572    0.002251  0.748469   3.828456      0.81426   0.60998
# 6   0.999401    0.003359  0.752212   3.988237      0.82040   0.59970
# ...

# %%
getFinalDf(task='iac_shuffle_0420', Type='both_sum')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.992594    0.024351  0.738770   2.129258      0.80696   0.59402
# 1   0.995633    0.017158  0.752895   2.701818      0.81988   0.60586
# 2   0.996147    0.013662  0.746085   3.213638      0.81586   0.59016
# 3   0.998588    0.006277  0.741492   3.569329      0.80910   0.59908
# 4   0.999016    0.003781  0.747108   3.791100      0.81304   0.60818
# 5   0.999272    0.002081  0.751531   3.921849      0.81826   0.60714
# 6   0.999572    0.001570  0.748299   3.980979      0.81730   0.59510
# ...

# %%
getFinalDf(task='iac_shuffle_0420', Type='both_concat')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.991353    0.028324  0.748807   2.262764      0.81368   0.61398
# 1   0.995762    0.017149  0.752212   3.220911      0.82090   0.59680
# 2   0.996789    0.015133  0.749490   3.755366      0.81852   0.59444
# 3   0.998159    0.006955  0.751875   3.948202      0.81624   0.61748
# 4   0.999016    0.004049  0.752386   4.385749      0.81944   0.60562
# 5   0.999101    0.003320  0.758171   4.468038      0.82358   0.61526
# 6   0.999272    0.002528  0.755446   4.674558      0.82394   0.59940
# ...

# %%
getFinalDf(task='iac_shuffle_0420', Type='hybrid')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.990026    0.034720  0.744726   2.312834      0.81048   0.60864
# 1   0.994050    0.026560  0.757149   3.320311      0.82346   0.61056
# 2   0.995291    0.023437  0.755788   3.917989      0.82150   0.61306
# 3   0.997988    0.009629  0.757830   4.440815      0.82096   0.62292
# 4   0.998716    0.005339  0.751533   4.682473      0.81602   0.61660
# 5   0.998502    0.004334  0.754426   4.813650      0.81722   0.62566
# 6   0.999144    0.002281  0.759532   4.873843      0.82588   0.61116
# ...

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='None').to_csv('./data/iac_0420_None.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='self_attention').to_csv('./data/iac_0420_self_attention.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='cross_attention').to_csv('./data/iac_0420_cross_attention.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='both_sum').to_csv('./data/iac_0420_both_sum.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='both_concat').to_csv('./data/iac_0420_both_concat.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle_0420', Type='hybrid').to_csv('./data/iac_0420_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf(task='iac', Type='hybrid')
# Out:
#    train_acc  train_cost  test_acc  test_cost  disagree_f1  agree_f1  \
# 0   0.988485    0.039136  0.745746   2.465401      0.81088   0.61146
# 1   0.994178    0.025804  0.750509   3.586048      0.81340   0.62320
# 2   0.995591    0.019500  0.747448   4.259937      0.81298   0.61052
# 3   0.997646    0.009235  0.747619   4.585820      0.81628   0.59678
# 4   0.998802    0.007746  0.751364   4.770350      0.81628   0.61366
# 5   0.999144    0.004285  0.752892   5.015709      0.81618   0.62148
# 6   0.999272    0.003039  0.755104   4.984238      0.82068   0.61370
# 7   0.999572    0.001932  0.754594   5.085629      0.81948   0.61674
# 8   0.999743    0.001632  0.754766   5.031998      0.81912   0.61826
# 9   0.999572    0.002633  0.757657   5.038383      0.82240   0.61832
#
#    average_f1
# 0     0.71117
# 1     0.71830
# 2     0.71175
# 3     0.70653
# 4     0.71497
# 5     0.71883
# 6     0.71719
# 7     0.71811
# 8     0.71869
# 9     0.72036

# %%
getFinalDf_v2(task='iac', Type='None').to_csv('./data/iac_None.csv')
getFinalDf_v2(task='iac', Type='share').to_csv('./data/iac_share.csv')
getFinalDf_v2(task='iac', Type='self_attention').to_csv('./data/iac_self_attention.csv')
getFinalDf_v2(task='iac', Type='cross_attention').to_csv('./data/iac_cross_attention.csv')
getFinalDf_v2(task='iac', Type='both_sum').to_csv('./data/iac_both_sum.csv')
getFinalDf_v2(task='iac', Type='both_concat').to_csv('./data/iac_both_concat.csv')
getFinalDf_v2(task='iac', Type='hybrid').to_csv('./data/iac_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='iac_shuffle', Type='None').to_csv('./data/iac_shuffle_None.csv')
getFinalDf_v2(task='iac_shuffle', Type='share').to_csv('./data/iac_shuffle_share.csv')
getFinalDf_v2(task='iac_shuffle', Type='self_attention').to_csv('./data/iac_shuffle_self_attention.csv')
getFinalDf_v2(task='iac_shuffle', Type='cross_attention').to_csv('./data/iac_shuffle_cross_attention.csv')
getFinalDf_v2(task='iac_shuffle', Type='both_sum').to_csv('./data/iac_shuffle_both_sum.csv')
getFinalDf_v2(task='iac_shuffle', Type='both_concat').to_csv('./data/iac_shuffle_both_concat.csv')
getFinalDf_v2(task='iac_shuffle', Type='hybrid').to_csv('./data/iac_shuffle_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='debatepedia', Type='None').to_csv('./data/debatepedia_None.csv')
getFinalDf_v2(task='debatepedia', Type='share').to_csv('./data/debatepedia_share.csv')
getFinalDf_v2(task='debatepedia', Type='self_attention').to_csv('./data/debatepedia_self_attention.csv')
getFinalDf_v2(task='debatepedia', Type='cross_attention').to_csv('./data/debatepedia_cross_attention.csv')
getFinalDf_v2(task='debatepedia', Type='both_sum').to_csv('./data/debatepedia_both_sum.csv')
getFinalDf_v2(task='debatepedia', Type='both_concat').to_csv('./data/debatepedia_both_concat.csv')
getFinalDf_v2(task='debatepedia', Type='hybrid').to_csv('./data/debatepedia_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='create_debate', Type='None').to_csv('./data/create_debate_None.csv')
getFinalDf_v2(task='create_debate', Type='share').to_csv('./data/create_debate_share.csv')
getFinalDf_v2(task='create_debate', Type='self_attention').to_csv('./data/create_debate_self_attention.csv')
getFinalDf_v2(task='create_debate', Type='cross_attention').to_csv('./data/create_debate_cross_attention.csv')
getFinalDf_v2(task='create_debate', Type='both_sum').to_csv('./data/create_debate_both_sum.csv')
getFinalDf_v2(task='create_debate', Type='both_concat').to_csv('./data/create_debate_both_concat.csv')
# getFinalDf_v2(task='create_debate', Type='hybrid').to_csv('./data/create_debate_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
getFinalDf_v2(task='create_debate_preTrain', Type='None').to_csv('./data/create_debate_preTrain_None.csv')
getFinalDf_v2(task='create_debate_preTrain', Type='share').to_csv('./data/create_debate_preTrain_share.csv')
getFinalDf_v2(task='create_debate_preTrain', Type='self_attention').to_csv('./data/create_debate_preTrain_self_attention.csv')
getFinalDf_v2(task='create_debate_preTrain', Type='cross_attention').to_csv('./data/create_debate_preTrain_cross_attention.csv')
getFinalDf_v2(task='create_debate_preTrain', Type='both_sum').to_csv('./data/create_debate_preTrain_both_sum.csv')
getFinalDf_v2(task='create_debate_preTrain', Type='both_concat').to_csv('./data/create_debate_preTrain_both_concat.csv')
# getFinalDf_v2(task='create_debate_preTrain', Type='hybrid').to_csv('./data/create_debate_preTrain_hybrid.csv')
# Out:
# /home/chandi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
