# %%
import pandas as pd

# %%
qrPair_df = pd.read_csv('./data/qrPair_2018.csv')

# %%
qrPair_df[59:]
# Out:
#         qrID                                          quoteText  \
# 59       9@3  i didnt mention good anywhere in my post this ...
# 60       9@4  biology is centered around the theory of evolu...
# 61       9@5          the queen does n't allow them to get sick
# 62       9@6  a woman owns her head , just as she owns the r...
# 63      10@0  so does this mean they have to get tougher on ...
# 64      10@1  washington , dc christopher bryan speight , th...
# 65      10@2     sex is a norman part of a healthy relationship
# 66      10@3  creationists are very open about the relations...
# 67      10@4  your answers were without content or meaning t...
# 68      10@5  for instance the yucca plant has a moth that w...
# 69      10@6  simple evolutionary science is science and cre...
# 70      11@0  hobbes specifically said that this is not the ...
# 71      11@1  and since when was there a dichotomy between f...
# 72      11@2                             the truth is out there
# ...

# %%
qrPair_df.iloc[1][1]
# Out:
# "be sure to give your guns a big fat kiss tonight before you go to bed tonight 'cuz guns did really good today"

# %%
qrPair_df.iloc[1][2]
# Out:
# "actually , they did n't the whole tragedy was caused by gun control if even one student was packing when that occured , 33 lives could have been saved but no , more victims of botched laws and corrupt politicians"
